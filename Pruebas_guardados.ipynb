# %% [markdown]
# <a href="https://colab.research.google.com/github/josuemayoral-cell/everpeak-analysis/blob/main/Pruebas_guardados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nuevo análisis: detectar outliers con IQR
Q1 = df['order_value'].quantile(0.25)
Q3 = df['order_value'].quantile(0.75)
IQR = Q3 - Q1
upper = Q3 + 1.5*IQR
df['outlier_flag'] = df['order_value'] > upper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4667/2338446722.py in <cell line: 0>()
#       1 # Nuevo análisis: detectar outliers con IQR
# ----> 2 Q1 = df['order_value'].quantile(0.25)
#       3 Q3 = df['order_value'].quantile(0.75)
#       4 IQR = Q3 - Q1
#       5 upper = Q3 + 1.5*IQR
#
# NameError: name 'df' is not defined
